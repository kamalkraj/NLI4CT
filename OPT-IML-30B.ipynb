# %%
import os
import json

import torch
import tqdm

from transformers import AutoModelForCausalLM, AutoTokenizer
# Out:
# 2023-02-05 15:15:51.727901: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
data = json.load(open("Complete_dataset/test.json"))
files = os.listdir("Complete_dataset/CT json/")
files.remove(".DS_Store")

# %%
files_data = {file[:-5]:json.load(open(f"Complete_dataset/CT json/{file}")) for file in files}

# %%
data_expanded = []
for _id, value in data.items():
    temp = {}
    temp["id"] = _id
    p_nctid = value["Primary_id"]
    s_nctid = value.get("Secondary_id")
    section_id = value["Section_id"]
    statement = value["Statement"]
    primary_evidence = files_data[p_nctid][section_id]
    temp["statement"] = statement
    temp["primary_evidence"] = primary_evidence
#     temp["label"] = value["Label"]
    
    if s_nctid is not None:
        secondary_evidence = files_data[s_nctid][section_id]
        temp["secondary_evidence"] = secondary_evidence
    
    data_expanded.append(temp)

# %%
tokenizer = AutoTokenizer.from_pretrained("facebook/opt-iml-max-30b")

# %%
model = AutoModelForCausalLM.from_pretrained("facebook/opt-iml-max-30b", torch_dtype=torch.float16).cuda()

# %%
def get_input_text(premise, hypothesis):
    options_prefix = "OPTIONS:\n- "
    separator = "\n- "
    options_ = options_prefix + f"{separator}".join(["Entailment","Contradiction"])
    return f"{premise} \n Question: Does this imply that {hypothesis}? {options_}\n A:"

# %%
samples = []
for sample in data_expanded:
    primary_evidence = "".join(sample['primary_evidence'])
    sentence = f"Primary trial evidence are {primary_evidence}"
    secondary_evidence = sample.get("secondary_evidence")
    if secondary_evidence:
        secondary_evidence = "".join(sample['secondary_evidence'])
        sentence = f"{sentence} Secondary trial evidence are {secondary_evidence}"
    input_text = get_input_text(sentence, sample['statement'])
    temp = {"text":input_text, "label":0}
    samples.append(temp)

# %%
labels = []
pred = []
with torch.inference_mode():
    for sample in tqdm.tqdm(samples):
        labels.append(sample["label"])
        input_ids = tokenizer(sample["text"], return_tensors="pt",).input_ids.to("cuda")
        outputs = model.generate(input_ids,max_new_tokens=8)
        pred.append(tokenizer.decode(outputs[0]))
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]/home/ubuntu/transformers/src/transformers/generation/utils.py:1273: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 20 (`generation_config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Input length of input_ids is 269, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   0%|          | 1/500 [00:06<50:03,  6.02s/it]Input length of input_ids is 138, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 178, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   1%|          | 3/500 [00:06<13:27,  1.62s/it]Input length of input_ids is 681, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   1%|          | 4/500 [00:06<09:32,  1.15s/it]Input length of input_ids is 456, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   1%|          | 5/500 [00:06<06:50,  1.21it/s]Input length of input_ids is 110, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1139, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   1%|▏         | 7/500 [00:07<04:31,  1.82it/s]Input length of input_ids is 1062, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   2%|▏         | 8/500 [00:07<04:10,  1.96it/s]Input length of input_ids is 121, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 311, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   2%|▏         | 10/500 [00:07<02:45,  2.96it/s]Input length of input_ids is 904, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   2%|▏         | 11/500 [00:08<02:42,  3.00it/s]Input length of input_ids is 938, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   2%|▏         | 12/500 [00:08<02:42,  3.01it/s]Input length of input_ids is 230, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   3%|▎         | 13/500 [00:08<02:12,  3.68it/s]Input length of input_ids is 176, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 878, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   3%|▎         | 15/500 [00:08<01:55,  4.21it/s]Input length of input_ids is 1035, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   3%|▎         | 16/500 [00:09<02:14,  3.61it/s]Input length of input_ids is 250, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   3%|▎         | 17/500 [00:09<01:52,  4.28it/s]Input length of input_ids is 680, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   4%|▎         | 18/500 [00:09<01:53,  4.24it/s]Input length of input_ids is 415, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   4%|▍         | 19/500 [00:09<01:45,  4.57it/s]Input length of input_ids is 367, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   4%|▍         | 20/500 [00:09<01:32,  5.17it/s]Input length of input_ids is 343, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   4%|▍         | 21/500 [00:10<01:24,  5.70it/s]Input length of input_ids is 130, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 597, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   5%|▍         | 23/500 [00:10<01:18,  6.06it/s]Input length of input_ids is 73, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   5%|▍         | 24/500 [00:10<01:19,  5.99it/s]Input length of input_ids is 926, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   5%|▌         | 25/500 [00:10<01:39,  4.80it/s]Input length of input_ids is 767, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   5%|▌         | 26/500 [00:11<01:47,  4.40it/s]Input length of input_ids is 210, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   5%|▌         | 27/500 [00:11<01:30,  5.20it/s]Input length of input_ids is 161, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 537, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   6%|▌         | 29/500 [00:11<01:20,  5.83it/s]Input length of input_ids is 359, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   6%|▌         | 30/500 [00:11<01:16,  6.15it/s]Input length of input_ids is 1274, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   6%|▌         | 31/500 [00:12<01:51,  4.20it/s]Input length of input_ids is 401, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   6%|▋         | 32/500 [00:12<01:43,  4.54it/s]Input length of input_ids is 319, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   7%|▋         | 33/500 [00:12<01:31,  5.12it/s]Input length of input_ids is 206, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 900, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   7%|▋         | 35/500 [00:12<01:34,  4.95it/s]Input length of input_ids is 548, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   7%|▋         | 36/500 [00:13<01:33,  4.94it/s]Input length of input_ids is 712, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   7%|▋         | 37/500 [00:13<01:38,  4.69it/s]Input length of input_ids is 175, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 1651, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   8%|▊         | 39/500 [00:14<02:10,  3.54it/s]Input length of input_ids is 409, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   8%|▊         | 40/500 [00:14<01:58,  3.89it/s]Input length of input_ids is 273, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   8%|▊         | 41/500 [00:14<01:43,  4.45it/s]Input length of input_ids is 1011, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   8%|▊         | 42/500 [00:14<01:59,  3.84it/s]Input length of input_ids is 545, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   9%|▊         | 43/500 [00:14<01:52,  4.06it/s]Input length of input_ids is 676, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   9%|▉         | 44/500 [00:15<01:51,  4.08it/s]Input length of input_ids is 452, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   9%|▉         | 45/500 [00:15<01:41,  4.47it/s]Input length of input_ids is 423, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#   9%|▉         | 46/500 [00:15<01:35,  4.78it/s]Input length of input_ids is 135, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 432, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#  10%|▉         | 48/500 [00:15<01:18,  5.77it/s]Input length of input_ids is 457, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#  10%|▉         | 49/500 [00:15<01:18,  5.74it/s]Input length of input_ids is 103, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 322, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#  10%|█         | 51/500 [00:16<01:04,  6.94it/s]Input length of input_ids is 416, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#  10%|█         | 52/500 [00:16<01:06,  6.71it/s]Input length of input_ids is 599, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#  11%|█         | 53/500 [00:16<01:13,  6.07it/s]Input length of input_ids is 172, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 510, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#  11%|█         | 55/500 [00:16<01:06,  6.66it/s]Input length of input_ids is 699, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#  11%|█         | 56/500 [00:17<01:17,  5.75it/s]Input length of input_ids is 119, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 347, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#  12%|█▏        | 58/500 [00:17<01:04,  6.84it/s]Input length of input_ids is 151, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# Input length of input_ids is 206, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
#  12%|█▏        | 60/500 [00:17<00:55,  7.93it/s]Input length of input_ids is 2846, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_new_tokens`.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [0,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [1,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [2,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [3,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [4,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [5,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [6,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [7,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [8,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [9,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [10,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [11,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [12,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [13,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [14,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [15,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [16,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [17,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [18,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [19,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [20,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [21,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [22,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [23,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [24,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [25,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [26,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [27,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [28,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [29,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [30,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [31,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [32,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [33,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [34,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [35,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [36,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [37,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [38,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [39,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [40,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [41,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [42,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [43,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [44,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [45,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [46,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [47,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [48,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [49,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [50,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [51,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [52,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [53,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [54,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [55,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [56,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [57,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [58,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [59,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [60,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [61,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [62,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [63,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [64,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [65,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [66,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [67,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [68,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [69,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [70,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [71,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [72,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [73,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [74,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [75,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [76,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [77,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [78,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [79,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [80,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [81,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [82,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [83,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [84,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [85,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [86,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [87,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [88,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [89,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [90,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [91,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [92,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [93,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [94,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [95,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [96,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [97,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [98,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [99,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [100,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [101,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [102,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [103,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [104,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [105,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [106,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [107,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [108,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [109,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [110,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [111,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [112,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [113,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [114,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [115,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [116,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [117,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [118,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [119,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [120,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [121,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [122,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [123,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [124,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [125,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [126,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [204,0,0], thread: [127,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [312,0,0], thread: [96,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [312,0,0], thread: [97,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [312,0,0], thread: [98,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [312,0,0], thread: [99,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [312,0,0], thread: [100,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [312,0,0], thread: [101,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [312,0,0], thread: [102,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [312,0,0], thread: [103,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [312,0,0], thread: [104,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [312,0,0], thread: [105,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [312,0,0], thread: [106,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [312,0,0], thread: [107,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [312,0,0], thread: [108,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [312,0,0], thread: [109,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [312,0,0], thread: [110,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [312,0,0], thread: [111,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [312,0,0], thread: [112,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [312,0,0], thread: [113,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [312,0,0], thread: [114,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [312,0,0], thread: [115,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [312,0,0], thread: [116,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [312,0,0], thread: [117,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [312,0,0], thread: [118,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [312,0,0], thread: [119,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [312,0,0], thread: [120,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [312,0,0], thread: [121,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [312,0,0], thread: [122,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [312,0,0], thread: [123,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [312,0,0], thread: [124,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [312,0,0], thread: [125,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [312,0,0], thread: [126,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [312,0,0], thread: [127,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [96,0,0], thread: [64,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [96,0,0], thread: [65,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [96,0,0], thread: [66,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [96,0,0], thread: [67,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [96,0,0], thread: [68,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [96,0,0], thread: [69,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [96,0,0], thread: [70,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [96,0,0], thread: [71,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [96,0,0], thread: [72,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [96,0,0], thread: [73,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [96,0,0], thread: [74,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [96,0,0], thread: [75,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [96,0,0], thread: [76,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [96,0,0], thread: [77,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [96,0,0], thread: [78,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [96,0,0], thread: [79,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [96,0,0], thread: [80,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [96,0,0], thread: [81,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [96,0,0], thread: [82,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [96,0,0], thread: [83,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [96,0,0], thread: [84,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [96,0,0], thread: [85,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [96,0,0], thread: [86,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [96,0,0], thread: [87,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [96,0,0], thread: [88,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [96,0,0], thread: [89,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [96,0,0], thread: [90,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [96,0,0], thread: [91,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [96,0,0], thread: [92,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [96,0,0], thread: [93,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [96,0,0], thread: [94,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [96,0,0], thread: [95,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [96,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [97,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [98,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [99,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [100,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [101,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [102,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [103,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [104,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [105,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [106,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [107,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [108,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [109,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [110,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [111,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [112,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [113,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [114,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [115,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [116,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [117,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [118,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [119,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [120,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [121,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [122,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [123,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [124,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [125,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [126,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [162,0,0], thread: [127,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [54,0,0], thread: [32,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [54,0,0], thread: [33,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [54,0,0], thread: [34,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [54,0,0], thread: [35,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [54,0,0], thread: [36,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [54,0,0], thread: [37,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [54,0,0], thread: [38,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [54,0,0], thread: [39,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [54,0,0], thread: [40,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [54,0,0], thread: [41,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1141: indexSelectLargeIndex: block: [54,0,0], thread: [42,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ...
# │   1392 │   │   │   │   input_ids,                                                                │
# │   1393 │   │   │   │   logits_processor=logits_processor,                                        │
# │   1394 │   │   │   │   stopping_criteria=stopping_criteria,                                      │
# │                                                                                                  │
# │ /home/ubuntu/transformers/src/transformers/generation/utils.py:2179 in greedy_search             │
# │                                                                                                  │
# │   2176 │   │   │   model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)  │
# │   2177 │   │   │                                                                                 │
# │   2178 │   │   │   # forward pass to get next token                                              │
# │ ❱ 2179 │   │   │   outputs = self(                                                               │
# │   2180 │   │   │   │   **model_inputs,                                                           │
# │   2181 │   │   │   │   return_dict=True,                                                         │
# │   2182 │   │   │   │   output_attentions=output_attentions,                                      │
# │                                                                                                  │
# │ /home/ubuntu/env/lib/python3.8/site-packages/torch/nn/modules/module.py:1194 in _call_impl       │
# │                                                                                                  │
# │   1191 │   │   # this function, and just call forward.                                           │
# │   1192 │   │   if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks o  │
# │   1193 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1194 │   │   │   return forward_call(*input, **kwargs)                                         │
# │   1195 │   │   # Do not call functions when jit is used                                          │
# │   1196 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1197 │   │   if self._backward_hooks or _global_backward_hooks:                                │
# │                                                                                                  │
# │ /home/ubuntu/env/lib/python3.8/site-packages/accelerate/hooks.py:156 in new_forward              │
# │                                                                                                  │
# │   153 │   │   │   with torch.no_grad():                                                          │
# │   154 │   │   │   │   output = old_forward(*args, **kwargs)                                      │
# │   155 │   │   else:                                                                              │
# │ ❱ 156 │   │   │   output = old_forward(*args, **kwargs)                                          │
# │   157 │   │   return module._hf_hook.post_forward(module, output)                                │
# │   158 │                                                                                          │
# │   159 │   module.forward = new_forward                                                           │
# │                                                                                                  │
# │ /home/ubuntu/transformers/src/transformers/models/opt/modeling_opt.py:934 in forward             │
# │                                                                                                  │
# │    931 │   │   return_dict = return_dict if return_dict is not None else self.config.use_return  │
# │    932 │   │                                                                                     │
# │    933 │   │   # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)   │
# │ ❱  934 │   │   outputs = self.model.decoder(                                                     │
# │    935 │   │   │   input_ids=input_ids,                                                          │
# │    936 │   │   │   attention_mask=attention_mask,                                                │
# │    937 │   │   │   head_mask=head_mask,                                                          │
# │                                                                                                  │
# │ /home/ubuntu/env/lib/python3.8/site-packages/torch/nn/modules/module.py:1194 in _call_impl       │
# │                                                                                                  │
# │   1191 │   │   # this function, and just call forward.                                           │
# │   1192 │   │   if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks o  │
# │   1193 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1194 │   │   │   return forward_call(*input, **kwargs)                                         │
# │   1195 │   │   # Do not call functions when jit is used                                          │
# │   1196 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1197 │   │   if self._backward_hooks or _global_backward_hooks:                                │
# │                                                                                                  │
# │ /home/ubuntu/transformers/src/transformers/models/opt/modeling_opt.py:698 in forward             │
# │                                                                                                  │
# │    695 │   │   │   │   )                                                                         │
# │    696 │   │   │   else:                                                                         │
# │    697 │   │   │   │                                                                             │
# │ ❱  698 │   │   │   │   layer_outputs = decoder_layer(                                            │
# │    699 │   │   │   │   │   hidden_states,                                                        │
# │    700 │   │   │   │   │   attention_mask=attention_mask,                                        │
# │    701 │   │   │   │   │   layer_head_mask=(head_mask[idx] if head_mask is not None else None),  │
# │                                                                                                  │
# │ /home/ubuntu/env/lib/python3.8/site-packages/torch/nn/modules/module.py:1194 in _call_impl       │
# │                                                                                                  │
# │   1191 │   │   # this function, and just call forward.                                           │
# │   1192 │   │   if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks o  │
# │   1193 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1194 │   │   │   return forward_call(*input, **kwargs)                                         │
# │   1195 │   │   # Do not call functions when jit is used                                          │
# │   1196 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1197 │   │   if self._backward_hooks or _global_backward_hooks:                                │
# │                                                                                                  │
# │ /home/ubuntu/env/lib/python3.8/site-packages/accelerate/hooks.py:156 in new_forward              │
# │                                                                                                  │
# │   153 │   │   │   with torch.no_grad():                                                          │
# │   154 │   │   │   │   output = old_forward(*args, **kwargs)                                      │
# │   155 │   │   else:                                                                              │
# │ ❱ 156 │   │   │   output = old_forward(*args, **kwargs)                                          │
# │   157 │   │   return module._hf_hook.post_forward(module, output)                                │
# │   158 │                                                                                          │
# │   159 │   module.forward = new_forward                                                           │
# │                                                                                                  │
# │ /home/ubuntu/transformers/src/transformers/models/opt/modeling_opt.py:327 in forward             │
# │                                                                                                  │
# │    324 │   │   │   hidden_states = self.self_attn_layer_norm(hidden_states)                      │
# │    325 │   │                                                                                     │
# │    326 │   │   # Self Attention                                                                  │
# │ ❱  327 │   │   hidden_states, self_attn_weights, present_key_value = self.self_attn(             │
# │    328 │   │   │   hidden_states=hidden_states,                                                  │
# │    329 │   │   │   past_key_value=past_key_value,                                                │
# │    330 │   │   │   attention_mask=attention_mask,                                                │
# │                                                                                                  │
# │ /home/ubuntu/env/lib/python3.8/site-packages/torch/nn/modules/module.py:1194 in _call_impl       │
# │                                                                                                  │
# │   1191 │   │   # this function, and just call forward.                                           │
# │   1192 │   │   if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks o  │
# │   1193 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1194 │   │   │   return forward_call(*input, **kwargs)                                         │
# │   1195 │   │   # Do not call functions when jit is used                                          │
# │   1196 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1197 │   │   if self._backward_hooks or _global_backward_hooks:                                │
# │                                                                                                  │
# │ /home/ubuntu/env/lib/python3.8/site-packages/accelerate/hooks.py:156 in new_forward              │
# │                                                                                                  │
# │   153 │   │   │   with torch.no_grad():                                                          │
# │   154 │   │   │   │   output = old_forward(*args, **kwargs)                                      │
# │   155 │   │   else:                                                                              │
# │ ❱ 156 │   │   │   output = old_forward(*args, **kwargs)                                          │
# │   157 │   │   return module._hf_hook.post_forward(module, output)                                │
# │   158 │                                                                                          │
# │   159 │   module.forward = new_forward                                                           │
# │                                                                                                  │
# │ /home/ubuntu/transformers/src/transformers/models/opt/modeling_opt.py:172 in forward             │
# │                                                                                                  │
# │    169 │   │   bsz, tgt_len, _ = hidden_states.size()                                            │
# │    170 │   │                                                                                     │
# │    171 │   │   # get query proj                                                                  │
# │ ❱  172 │   │   query_states = self.q_proj(hidden_states) * self.scaling                          │
# │    173 │   │   # get key, value proj                                                             │
# │    174 │   │   if is_cross_attention and past_key_value is not None:                             │
# │    175 │   │   │   # reuse k,v, cross_attentions                                                 │
# │                                                                                                  │
# │ /home/ubuntu/env/lib/python3.8/site-packages/torch/nn/modules/module.py:1194 in _call_impl       │
# │                                                                                                  │
# │   1191 │   │   # this function, and just call forward.                                           │
# │   1192 │   │   if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks o  │
# │   1193 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1194 │   │   │   return forward_call(*input, **kwargs)                                         │
# │   1195 │   │   # Do not call functions when jit is used                                          │
# │   1196 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1197 │   │   if self._backward_hooks or _global_backward_hooks:                                │
# │                                                                                                  │
# │ /home/ubuntu/env/lib/python3.8/site-packages/accelerate/hooks.py:156 in new_forward              │
# │                                                                                                  │
# │   153 │   │   │   with torch.no_grad():                                                          │
# │   154 │   │   │   │   output = old_forward(*args, **kwargs)                                      │
# │   155 │   │   else:                                                                              │
# │ ❱ 156 │   │   │   output = old_forward(*args, **kwargs)                                          │
# │   157 │   │   return module._hf_hook.post_forward(module, output)                                │
# │   158 │                                                                                          │
# │   159 │   module.forward = new_forward                                                           │
# │                                                                                                  │
# │ /home/ubuntu/env/lib/python3.8/site-packages/torch/nn/modules/linear.py:114 in forward           │
# │                                                                                                  │
# │   111 │   │   │   init.uniform_(self.bias, -bound, bound)                                        │
# │   112 │                                                                                          │
# │   113 │   def forward(self, input: Tensor) -> Tensor:                                            │
# │ ❱ 114 │   │   return F.linear(input, self.weight, self.bias)                                     │
# │   115 │                                                                                          │
# │   116 │   def extra_repr(self) -> str:                                                           │
# │   117 │   │   return 'in_features={}, out_features={}, bias={}'.format(                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# RuntimeError: CUDA error: CUBLAS_STATUS_EXECUTION_FAILED when calling `cublasLtMatmul( ltHandle,
# computeDesc.descriptor(), &alpha_val, mat1_ptr, Adesc.descriptor(), mat2_ptr, Bdesc.descriptor(), &beta_val,
# result_ptr, Cdesc.descriptor(), result_ptr, Cdesc.descriptor(), &heuristicResult.algo, workspace.data_ptr(),
# workspaceSize, at::cuda::getCurrentCUDAStream())`

# %%
pred
# Out:
# ['<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>']

# %%
pred = [p[5:][:-4].strip() for p in pred]

# %%
print(set(pred))
from collections import Counter
# Out:
# {'Contradiction', 'Entailment'}

# %%
Counter(pred)
# Out:
# Counter({'Contradiction': 264, 'Entailment': 236})

# %%
prediction_dict = {}
for _id,pred_x in zip(data, pred):
    prediction_dict[str(_id)] = {"Prediction":pred_x}

# %%
json.dump(prediction_dict, open("results.json",'w'),indent=4)

# %%
# !zip results_xxl_train_1024_2_7e_6_Dev_repro.zip results.json
# Out:
#   adding: results.json (deflated 73%)

# %%
prediction_dict
# Out:
# {'9f978634-637c-472f-a588-6f4bb2fb121f': {'Prediction': 'Contradiction'},
#  '20b34e62-97c2-4ca0-bb1d-7824dab0b8bb': {'Prediction': 'Entailment'},
#  '893a5337-2aa9-4a87-a020-4c2f03cd4aea': {'Prediction': 'Entailment'},
#  'd401affc-f081-4eee-bd61-d109cc88f6de': {'Prediction': 'Entailment'},
#  '791790a6-187b-4e4b-be5f-9e5304e9ec2c': {'Prediction': 'Contradiction'},
#  'b95b7438-ec16-4d4d-826d-5891e7982b36': {'Prediction': 'Entailment'},
#  '4988cb16-7dbb-4847-84e0-4a7957b32c72': {'Prediction': 'Entailment'},
#  'e244fc3a-53b3-4158-99c5-a45afc726af6': {'Prediction': 'Contradiction'},
#  '56530063-b408-47f2-8421-6be825f5559c': {'Prediction': 'Entailment'},
#  'd3379655-55b7-4e58-88c2-c3cd3e8cb557': {'Prediction': 'Contradiction'},
#  '7bf988b4-5e6f-41c4-bef6-7b3549dd58d9': {'Prediction': 'Contradiction'},
#  '84915e35-a8c9-4d26-ad09-4b1df48a6df8': {'Prediction': 'Entailment'},
#  '64df451c-f868-49e6-9b4e-a325e62ce837': {'Prediction': 'Entailment'},
#  'dc4765a3-6168-4594-969b-3ce5ea7dc02a': {'Prediction': 'Contradiction'},
#  '9c2ca035-d531-4d44-876e-6ed9f2d3f76b': {'Prediction': 'Entailment'},
#  '7238ddd4-eade-4b88-8933-0c3df5be9875': {'Prediction': 'Contradiction'},
#  'aeddc485-09b1-4ddc-9a45-3a8bf0bec2c3': {'Prediction': 'Entailment'},
#  '204d5293-d6e5-452a-8961-3b76d6be35c9': {'Prediction': 'Entailment'},
#  '4ed1c5fd-58e5-4fe8-97b1-59ed509ccb10': {'Prediction': 'Entailment'},
#  '6d0812b9-f9bd-4cd6-82aa-9c272eba23be': {'Prediction': 'Contradiction'},
#  'fd0fa999-2f1c-400d-977d-2d45dd9c358c': {'Prediction': 'Contradiction'},
#  '571d4650-e64b-4cb2-b719-0d7064e51745': {'Prediction': 'Contradiction'},
#  '4437aa5b-4b4e-4eb4-a258-e7f17dc8f363': {'Prediction': 'Contradiction'},
#  'd7abbd7d-a767-49c0-bc99-1c28074eac21': {'Prediction': 'Contradiction'},
#  '54c7e880-a1bf-4206-9573-1c994932ba15': {'Prediction': 'Entailment'},
#  'f9f0ba74-16e0-4790-afa0-b7616b256e5e': {'Prediction': 'Entailment'},
#  '412583db-ce19-451d-a804-3837e4dcaea3': {'Prediction': 'Contradiction'},
#  'bca4c94d-4a49-4e05-82ed-0d5c9707685b': {'Prediction': 'Entailment'},
#  '97acf304-2707-4a1b-81e7-339fde2ed0ee': {'Prediction': 'Contradiction'},
#  '21a5f296-5b3c-4860-be64-77ffb8f76501': {'Prediction': 'Entailment'},
#  '8d27bb53-e66e-4eab-bea4-0597fd5760b5': {'Prediction': 'Entailment'},
#  'dc60304d-6fd2-4b12-9108-b5ce78454d42': {'Prediction': 'Contradiction'},
#  '328417f9-8f45-4114-82d7-9396b6bc578e': {'Prediction': 'Contradiction'},
#  '40d84c7b-e126-4d6f-9588-eb9c385ca716': {'Prediction': 'Contradiction'},
#  'b685be77-9c55-4948-99cc-2a249739a233': {'Prediction': 'Entailment'},
#  '5fbee4f6-43fc-45a7-88c4-3dcd5ff21053': {'Prediction': 'Entailment'},
#  '8127d46a-3a48-4173-8d00-75e949755a74': {'Prediction': 'Contradiction'},
#  '576967ff-d2bb-4d1c-b2a1-8516ceb7a519': {'Prediction': 'Contradiction'},
#  'fd334e71-2bbe-4138-b578-2ab848686045': {'Prediction': 'Entailment'},
#  'a72ddea5-ee4b-4895-bd8c-10b4a143c3f8': {'Prediction': 'Contradiction'},
#  '6c29e8c1-36ca-4e6e-b4dc-f1e91b98e546': {'Prediction': 'Contradiction'},
#  'd1118512-9c0b-4480-ab67-d4e0c7de390d': {'Prediction': 'Contradiction'},
#  'd35e9b96-20fc-4778-a7db-e87c861c4938': {'Prediction': 'Entailment'},
#  '25b01c06-612c-4cfb-b30b-50ebe4d98750': {'Prediction': 'Entailment'},
#  '1a76bce8-07e2-4b30-adc8-3c095f0d62b3': {'Prediction': 'Contradiction'},
#  '23f84ae0-fd01-4799-8872-118e22a015e8': {'Prediction': 'Contradiction'},
#  'c2aea351-6ce5-4d26-9ba5-2632c6367b93': {'Prediction': 'Entailment'},
#  '388cc99c-4cb3-4ff9-9496-07f4a6bf6ac7': {'Prediction': 'Contradiction'},
#  '5af6aa8c-69f5-44a5-9c7c-6c94a0fda6e8': {'Prediction': 'Contradiction'},
#  '455d059c-c3c4-4a09-be0d-a14b9568a0d2': {'Prediction': 'Entailment'},
#  '6d37ed53-a6e4-403e-8b93-9954a6486dbc': {'Prediction': 'Entailment'},
#  'e530eed4-ee8b-4a7f-bb36-5ce9ea7ddebe': {'Prediction': 'Contradiction'},
#  '41a0138d-7084-40d9-99ae-24db9e84acce': {'Prediction': 'Entailment'},
#  '11cb71ed-1304-42f0-b416-3679c3e9e1b3': {'Prediction': 'Contradiction'},
#  '6ddf4b5b-69e2-46e1-b032-69c3173fd8ef': {'Prediction': 'Entailment'},
#  '9349c7c8-7771-4dfc-8981-3c8d84ac5236': {'Prediction': 'Entailment'},
#  '4e91cee2-910e-4f08-8a85-1f13545391c3': {'Prediction': 'Contradiction'},
#  '18c281a1-43bd-47f5-9534-feddfcf0a282': {'Prediction': 'Contradiction'},
#  'dd3d2183-d062-41ed-af63-ae475f2246ec': {'Prediction': 'Contradiction'},
#  '711fdd40-52ec-401c-90fc-5a11de547ab6': {'Prediction': 'Entailment'},
#  '49b3b463-a496-404a-a3a5-07cd7d4aaa92': {'Prediction': 'Entailment'},
#  '43b9c2c8-0785-4885-901b-91a1f893858f': {'Prediction': 'Entailment'},
#  '43989f85-a059-4dc7-a805-16e081706b2f': {'Prediction': 'Entailment'},
#  '282a33db-aed6-4daa-bea6-299f424914bb': {'Prediction': 'Contradiction'},
#  '646691ba-ad29-479f-81dc-131d9710c23b': {'Prediction': 'Entailment'},
#  'a0c1da21-1e1f-493b-81e9-4ef133c20090': {'Prediction': 'Contradiction'},
#  '439b1eca-f583-4a2b-bd8e-0baae97b4c15': {'Prediction': 'Contradiction'},
#  'e12e5ed1-9a64-4183-9b9d-419e6679ab3d': {'Prediction': 'Entailment'},
#  '73849f1e-31c6-40c5-ab5c-35d0990ceac2': {'Prediction': 'Entailment'},
#  'f53c5344-36d7-459f-9f84-300e19decced': {'Prediction': 'Entailment'},
#  '77fd9a89-4d9b-40ab-b4ad-fcf554ca68d2': {'Prediction': 'Entailment'},
#  '99433bba-fce5-4b0a-a076-1f699b51472d': {'Prediction': 'Entailment'},
#  '135763e3-70fd-478d-991c-717d6ed55bb3': {'Prediction': 'Entailment'},
#  '6cbfc99b-6531-412f-bd30-b4a803983831': {'Prediction': 'Entailment'},
#  '6a3053ef-4495-4c18-9da7-68cf5ed254e0': {'Prediction': 'Contradiction'},
#  '217b0362-9dd0-4f10-8ca5-c097688bb738': {'Prediction': 'Contradiction'},
#  'd88235dd-c37b-4971-9c1f-42b282ff41c1': {'Prediction': 'Contradiction'},
#  'e6bbed17-0fdf-4008-b56e-4d901490ce1a': {'Prediction': 'Entailment'},
#  'f1f9d4b4-4877-49ad-a2e2-f53efbe40ef9': {'Prediction': 'Entailment'},
#  '8393ad3d-8521-4316-b69e-64910d8af5e7': {'Prediction': 'Contradiction'},
#  'cca11232-84c4-44e1-89f1-b57b28643dce': {'Prediction': 'Contradiction'},
#  'cb36e435-6dc9-4e7b-939b-9da6ceef2a49': {'Prediction': 'Contradiction'},
#  '7ce21c0f-ad55-4ff7-a180-5e418fe9afc8': {'Prediction': 'Entailment'},
#  '42c38d71-6a83-4967-ad81-ec38c6b5aafd': {'Prediction': 'Entailment'},
#  '6c5ebc06-00c4-4cf5-8912-93972ed5a49b': {'Prediction': 'Entailment'},
#  '32cc173a-b271-47c9-997d-df17ce1c7494': {'Prediction': 'Entailment'},
#  'b742bc02-cd24-4ae7-b8b8-2a57bbd60d14': {'Prediction': 'Entailment'},
#  '334b5f86-50c5-4711-994d-31ed67dd4282': {'Prediction': 'Entailment'},
#  '04178e95-d808-4a96-ab85-61eb52c17720': {'Prediction': 'Contradiction'},
#  '18d3b58f-42ca-4178-adb6-4a5f0c9fafde': {'Prediction': 'Entailment'},
#  'cfa6601b-af52-4eee-883c-89d42b73e02b': {'Prediction': 'Entailment'},
#  'f58fda4c-f4fd-44a7-8a0f-5d3a16929709': {'Prediction': 'Entailment'},
#  'e52afcaa-e5d8-4a1f-ae39-8572a64b0aee': {'Prediction': 'Entailment'},
#  '96042d49-2f5a-44af-8899-2d5ba24c0f6f': {'Prediction': 'Entailment'},
#  '587e611a-9c3b-4557-b3ca-56a7dcc6ce1b': {'Prediction': 'Entailment'},
#  'ea3a7d64-b464-4633-a198-794a4a45b201': {'Prediction': 'Entailment'},
#  '58165e03-4aa6-4d0c-8256-dbc92ee900c4': {'Prediction': 'Contradiction'},
#  'fa7b34e2-75e6-4bc4-a154-99be5bd6b381': {'Prediction': 'Entailment'},
#  '7b9338a5-d3a8-405f-a197-736caf32c455': {'Prediction': 'Contradiction'},
#  '8f078a17-14cd-4bbc-a9b6-b377ffa077b5': {'Prediction': 'Contradiction'},
#  '2d36fa83-b68c-420e-873f-e69374d0741f': {'Prediction': 'Contradiction'},
#  '6e1489a6-3a42-4b52-b690-fb1dd8892749': {'Prediction': 'Entailment'},
#  'de6b5ea7-b593-43b7-8fe0-358991878e86': {'Prediction': 'Entailment'},
#  'fe5928a4-1a0c-4c41-9b85-8d7785a8ab4c': {'Prediction': 'Contradiction'},
#  '827af363-cfd3-4233-9029-e8c7e053c661': {'Prediction': 'Contradiction'},
#  '3c9a4b79-1f51-477a-a5b6-b69f76aeedf8': {'Prediction': 'Contradiction'},
#  '98b04dac-b155-4afd-8855-03ed818df5d9': {'Prediction': 'Entailment'},
#  '7eeeed55-fe37-47ae-be62-e50557ccaed1': {'Prediction': 'Entailment'},
#  'cbc96b9d-b39c-4fbe-b8a7-e7df7490881b': {'Prediction': 'Contradiction'},
#  '2a05996c-d5fb-4aa8-9654-fb1d27180888': {'Prediction': 'Entailment'},
#  'da24d6fd-1363-489b-ac5a-f44dbe622c5d': {'Prediction': 'Contradiction'},
#  '437d5311-f0fd-4d61-82a2-5db0d07415f6': {'Prediction': 'Entailment'},
#  'af0e8d9b-f748-424d-a4e7-6bb3bf0ee7a2': {'Prediction': 'Entailment'},
#  '2bd78232-4872-4d66-ade9-836190b86e1d': {'Prediction': 'Contradiction'},
#  '80a26581-a95c-4c22-864f-93425b1fc165': {'Prediction': 'Entailment'},
#  '4c926c31-8786-47b0-a032-1d59f759bca5': {'Prediction': 'Entailment'},
#  '62384871-8eb2-414b-8cc9-e756a188e19e': {'Prediction': 'Contradiction'},
#  'a6e81477-f863-4a83-9007-fd2f1f5c6781': {'Prediction': 'Entailment'},
#  '2312576f-7c8d-4fcd-80e8-42cf3d81dd04': {'Prediction': 'Contradiction'},
#  '8f4d4e78-5e46-47b6-865c-ad6b689d69e0': {'Prediction': 'Contradiction'},
#  'a8268e5e-d758-4dcf-8dd9-78c2016bc7f6': {'Prediction': 'Entailment'},
#  'd53cf5fe-1104-4b05-886c-bb5499cdc047': {'Prediction': 'Contradiction'},
#  '1bd849aa-409c-4214-a930-4d187a645466': {'Prediction': 'Contradiction'},
#  'a5415a49-0b04-4f8f-a7ec-a8c276b2cf64': {'Prediction': 'Entailment'},
#  '5578e4a3-95d9-4803-8d13-b9c0276f92e0': {'Prediction': 'Contradiction'},
#  '5e92a3fd-5ffa-49db-9978-897321839068': {'Prediction': 'Contradiction'},
#  '539bf07d-199d-4c9b-af16-5f314962bcfc': {'Prediction': 'Contradiction'},
#  '00831e0c-eaad-4fe9-a791-f105815fa215': {'Prediction': 'Contradiction'},
#  '0a266c52-2a4e-4aed-a04c-85c148f2cd41': {'Prediction': 'Entailment'},
#  '4e5a04a1-2513-472b-b2a7-891d68a3b549': {'Prediction': 'Entailment'},
#  '6734e552-d882-446e-a02f-c6bbe2eeb6ed': {'Prediction': 'Entailment'},
#  '3ab9a40f-bbd8-43ed-a468-7fdbe3d9ce19': {'Prediction': 'Entailment'},
#  '3a4198ab-ae79-4200-b073-860b2e86813d': {'Prediction': 'Contradiction'},
#  '327d67d2-35e7-45c3-958a-7955905f2d57': {'Prediction': 'Entailment'},
#  'a1807b6a-6ee6-4c74-bf44-53d39c31c66f': {'Prediction': 'Contradiction'},
#  'df39cd99-7291-4749-a7d5-ff760b7c3fc2': {'Prediction': 'Entailment'},
#  '54a1eab3-1e8e-4c1c-a30f-f4d677a84c71': {'Prediction': 'Entailment'},
#  'cc6601cf-3aa0-44f7-8476-f3dfc34e7412': {'Prediction': 'Contradiction'},
#  '7d60c7dd-fb79-4e95-a662-32de2036683f': {'Prediction': 'Entailment'},
#  'c12d4dba-17b9-45d6-9a3f-75be190b7795': {'Prediction': 'Entailment'},
#  '8aca5f0b-c998-4e51-9e53-e23294e61867': {'Prediction': 'Contradiction'},
#  '88857141-6207-4828-b8d4-09d7cc4498c3': {'Prediction': 'Entailment'},
#  '9d9fc91e-b6a2-4ab8-bb28-a0a182574d90': {'Prediction': 'Entailment'},
#  'c43d1ac6-f3d2-44f6-870d-fb91f3365c5b': {'Prediction': 'Contradiction'},
#  'f03664fa-20b3-4102-b1e2-fe901d028f65': {'Prediction': 'Entailment'},
#  '95cb9c0a-0725-4108-aebb-f114f77b577c': {'Prediction': 'Entailment'},
#  '726add6d-9f17-4e3e-a43e-8b391fbb953b': {'Prediction': 'Contradiction'},
#  '8c07a493-66a5-4728-ae22-d6c45b2215a8': {'Prediction': 'Entailment'},
#  '9340e38d-37ce-4634-9f36-a747f964441c': {'Prediction': 'Contradiction'},
#  'b20cbb69-8909-4a66-b47c-27192604d187': {'Prediction': 'Entailment'},
#  'b5f68d8f-0c92-4f58-9740-78556c039e58': {'Prediction': 'Contradiction'},
#  'd475c476-8172-47a0-bf91-7ef5d0f6d081': {'Prediction': 'Contradiction'},
#  '7f6d7fd9-8aed-472d-af54-b288d16c2135': {'Prediction': 'Contradiction'},
#  '49c63fc5-be4b-4474-8bfc-0ddf9cf438db': {'Prediction': 'Contradiction'},
#  '5887ed1d-aa43-4a18-be3a-9141b675d5af': {'Prediction': 'Entailment'},
#  'fa6115aa-a765-4d03-9fd0-61c97d5e282f': {'Prediction': 'Contradiction'},
#  '5a916856-536f-444d-87e7-1b2c032c0656': {'Prediction': 'Entailment'},
#  '26145056-fdfd-4f2d-909e-be84fc53ede8': {'Prediction': 'Contradiction'},
#  'ceb02a85-73a3-4c00-823e-fb88bc91d239': {'Prediction': 'Entailment'},
#  '3cae8899-5172-460e-8ff1-e6e1c8a59f0b': {'Prediction': 'Entailment'},
#  '8367e2fc-f384-43c0-af4e-d4ec41281b2e': {'Prediction': 'Entailment'},
#  '20493bc1-bda8-4255-a1d4-40cb499bd845': {'Prediction': 'Entailment'},
#  '93eef0e8-7a40-452a-a61e-a9d671dcacbd': {'Prediction': 'Entailment'},
#  '3d9a7121-da16-4e7b-a02d-1932f46cbb77': {'Prediction': 'Entailment'},
#  'e2979c27-0eb6-487d-a940-646685e1934b': {'Prediction': 'Entailment'},
#  '5abfa152-2c23-40b4-ba00-b28336b8b8b5': {'Prediction': 'Entailment'},
#  '251e979f-a7ba-4dea-afb7-01b9501ec7cf': {'Prediction': 'Contradiction'},
#  '7eab2fc5-fd40-40bc-a960-90aafe45ef9e': {'Prediction': 'Entailment'},
#  'a6299338-84c5-469d-9bd0-eff13b90a7eb': {'Prediction': 'Entailment'},
#  '5e5253e5-fd72-4f2b-84ba-b370545cd182': {'Prediction': 'Contradiction'},
#  '5e301f1c-087e-4ca4-b679-cc229d1c0d27': {'Prediction': 'Entailment'},
#  '0967b501-90dd-4ba4-bebc-8db1e9695431': {'Prediction': 'Entailment'},
#  '8101ccf6-e6f4-43ba-b22f-9a13e2ddd279': {'Prediction': 'Contradiction'},
#  '292d0dd3-1b9c-4291-b367-0cc1666178db': {'Prediction': 'Contradiction'},
#  'ef1d6dfa-2cd0-4e19-99b7-a813d6952706': {'Prediction': 'Entailment'},
#  '86ed4db6-24fe-4a88-ba9b-6be3f98e0525': {'Prediction': 'Contradiction'},
#  'd71c6377-89da-457d-acbc-827be4ddb8e5': {'Prediction': 'Entailment'},
#  '74aebfd6-c201-4c6f-a7af-7e4e0de6b661': {'Prediction': 'Entailment'},
#  '886a066c-520e-4454-bf20-43ad24b6baf9': {'Prediction': 'Contradiction'},
#  '2a95f6b8-fbdd-47e6-949f-8aee18a2c605': {'Prediction': 'Contradiction'},
#  '15d7d028-69c2-4e01-b85c-cff568f34cc1': {'Prediction': 'Contradiction'},
#  'fdadf425-1eaf-4e63-b034-29afcbe48baf': {'Prediction': 'Contradiction'},
#  '3ad9820f-4ef2-4624-b08a-b910adf25836': {'Prediction': 'Entailment'},
#  'afdafe17-63a8-4fca-b923-a2bb964493d1': {'Prediction': 'Entailment'},
#  'a0428861-8e0f-42ca-889f-b2546ae3dbe6': {'Prediction': 'Contradiction'},
#  'e6e3ecde-9d81-41a2-849e-de26c1b9bafc': {'Prediction': 'Entailment'},
#  'f8a72a9e-357d-4786-8d5d-66ee4ce4d1b2': {'Prediction': 'Entailment'},
#  '81521795-13b4-46d4-a03e-51ab823e9756': {'Prediction': 'Entailment'},
#  'b29091a1-befa-4edc-9bc9-06263826bfdd': {'Prediction': 'Entailment'},
#  '593bde37-5962-441b-ac10-dbe3120cec99': {'Prediction': 'Entailment'},
#  'd85fd7f3-2765-407e-a8a3-49c19d9a4311': {'Prediction': 'Contradiction'},
#  'b6902408-8d60-438b-bb38-416d4a4d76fb': {'Prediction': 'Entailment'},
#  'c484c0e8-0530-47cb-89dc-da4c4a7f4c0b': {'Prediction': 'Contradiction'},
#  '7270c176-7bf2-4b0d-941d-912f5a3ed62c': {'Prediction': 'Entailment'},
#  '8be0e7b4-f74d-4205-a543-1247762bb467': {'Prediction': 'Entailment'},
#  '2c4acb3d-7009-4a19-ac0e-703a96740738': {'Prediction': 'Entailment'},
#  '401f0d8c-4f4e-4693-8baa-3ae8664480d3': {'Prediction': 'Contradiction'},
#  '67f1754a-420c-4605-a41d-784c4d1e77b0': {'Prediction': 'Contradiction'},
#  '9727b232-81fc-42cc-bd06-05cc81a7453b': {'Prediction': 'Contradiction'},
#  '1cdbbd44-21df-4279-9e3c-ff501f1361ec': {'Prediction': 'Entailment'},
#  '78aec7ae-20b1-413b-9cb7-9757274ff1aa': {'Prediction': 'Entailment'},
#  'b3b66b49-6a4c-4c26-b46c-915ab45374ff': {'Prediction': 'Contradiction'},
#  '73876da9-0c79-43eb-9d1f-b7f2d729f43c': {'Prediction': 'Entailment'},
#  '9c7521a7-87fc-4dc0-8c1e-5720836763e2': {'Prediction': 'Contradiction'},
#  'ffacecd7-caae-434a-866d-a3a25d4f00ac': {'Prediction': 'Entailment'},
#  '458419cf-ea6f-4939-ba2e-856b8d89b985': {'Prediction': 'Entailment'},
#  '7482499c-6836-4f68-83f4-4af09b14d566': {'Prediction': 'Entailment'},
#  'a0d99371-52e5-4d30-81d5-ad65feba2e4e': {'Prediction': 'Entailment'},
#  '47bcd1c5-f95d-4e21-a999-4bd220c5b940': {'Prediction': 'Entailment'},
#  'cc411bc6-900e-4ef3-96ef-09f6e5565a18': {'Prediction': 'Entailment'},
#  '1943100e-196d-4022-a38a-9ae0dd816294': {'Prediction': 'Entailment'},
#  'd11356c5-cf48-40dc-aa23-46e71f564afd': {'Prediction': 'Entailment'},
#  'f8e8c733-3fc0-4699-814f-b5d505c71435': {'Prediction': 'Contradiction'},
#  'dfea11ab-1a3f-4a76-9fae-96d486f76e10': {'Prediction': 'Entailment'},
#  '285b3905-8e47-4b26-8aa5-2d9d7f717a6c': {'Prediction': 'Entailment'},
#  '92935ccc-f20d-4e27-9a5f-cb8d47162de6': {'Prediction': 'Entailment'},
#  '74308ad0-4b9d-4632-9580-5e280dedbc77': {'Prediction': 'Entailment'},
#  '487dd970-35e7-4a7d-8bb6-e8fa98f574aa': {'Prediction': 'Contradiction'},
#  '1cda1a1d-3ca1-4838-9054-bcab763bb5d0': {'Prediction': 'Contradiction'},
#  '9228fe22-ca97-4ca9-ad78-f8dba1ac27b0': {'Prediction': 'Contradiction'},
#  'aecd2958-c3b4-4d87-82f1-07add215b1e8': {'Prediction': 'Contradiction'},
#  '590f240e-7499-432e-aa3c-f54eda69ed46': {'Prediction': 'Contradiction'},
#  '561d1a70-6bd1-42f7-9e2a-73b9622a449c': {'Prediction': 'Entailment'},
#  '1af4d0ac-d0f2-402a-8bdb-0e10c0823b0f': {'Prediction': 'Contradiction'},
#  'c8235719-3fd8-43e9-8ba6-d99393220240': {'Prediction': 'Contradiction'},
#  '837329c4-d046-4997-ad41-f230d3db7255': {'Prediction': 'Contradiction'},
#  'e1040054-0fe6-4c92-be82-f2b5b79282a5': {'Prediction': 'Entailment'},
#  '282c18a2-64b1-47cf-8563-db8db40dadb6': {'Prediction': 'Entailment'},
#  'f4e0551c-44e9-44f1-9a50-c65075a51715': {'Prediction': 'Contradiction'},
#  'cbba3546-5b88-42d0-882d-024d5f267d97': {'Prediction': 'Entailment'},
#  'ea1d804d-bac9-4ebd-a6bd-0705c988927f': {'Prediction': 'Entailment'},
#  'fdd9ccc8-95c0-48d9-bc4d-3ef7469dbb9a': {'Prediction': 'Contradiction'},
#  '17413685-69fd-453f-af49-29982a6c95b6': {'Prediction': 'Entailment'},
#  '10292ba1-dd1f-4191-b534-331f39583181': {'Prediction': 'Entailment'},
#  'e78805f7-1b81-4cd9-a3c7-591886fd5d70': {'Prediction': 'Contradiction'},
#  '42857f32-4798-4767-a0c7-f74cdcab7a9b': {'Prediction': 'Contradiction'},
#  '9c2adaba-1ac9-4a7c-a710-14ac7d2056fd': {'Prediction': 'Contradiction'},
#  'af55082d-0ff1-419f-861f-80dbd05a9ade': {'Prediction': 'Contradiction'},
#  '3a0c092c-7e18-4108-ae66-552f7069831f': {'Prediction': 'Contradiction'},
#  '3a452f00-375b-48c4-96dd-48986c0c0064': {'Prediction': 'Contradiction'},
#  'c94158fd-10f5-4142-a361-5b346ff2c295': {'Prediction': 'Contradiction'},
#  '577c7755-64ae-4b78-bbe3-627cef6e3ece': {'Prediction': 'Contradiction'},
#  '5b94480e-aa25-491e-ae37-a2b2939eafaf': {'Prediction': 'Entailment'},
#  '494a4094-5a05-4c7d-b7a7-60baeb210e5a': {'Prediction': 'Entailment'},
#  '5b13bca4-0354-4579-a868-d007bef0dbe1': {'Prediction': 'Entailment'},
#  '623db2b4-6824-42e4-9ad6-39cf3bf14dab': {'Prediction': 'Entailment'},
#  'a793df3f-fa04-4d48-a2c6-006589d52e84': {'Prediction': 'Entailment'},
#  '75961bc5-20b9-4161-83e0-a59429ce18e9': {'Prediction': 'Contradiction'},
#  'd94a09b9-8201-43f3-9b27-cab0bc473af0': {'Prediction': 'Entailment'},
#  '6920329b-7559-415e-9346-c06909526421': {'Prediction': 'Entailment'},
#  '85d61aaf-5255-4203-9ccf-f9c3da7a352e': {'Prediction': 'Contradiction'},
#  '22384b11-eb42-42da-86b3-dfed559ebb77': {'Prediction': 'Entailment'},
#  '0c73bdd4-7244-433c-8b5e-bf335f21701c': {'Prediction': 'Contradiction'},
#  'b9b156ee-526a-49ac-aa99-78f02a24dbaf': {'Prediction': 'Contradiction'},
#  '3974c3ec-d3b5-4313-ae4b-4332ee5865ab': {'Prediction': 'Contradiction'},
#  'b358fb9c-1152-4e1a-88eb-743e965d58fc': {'Prediction': 'Entailment'},
#  '06b8d395-0fe7-4206-b118-5e478779cce0': {'Prediction': 'Entailment'},
#  'a911fcee-0621-4f06-a511-b8323ab8440c': {'Prediction': 'Entailment'},
#  '68f673a5-6ddf-487a-ad88-4903d92e1746': {'Prediction': 'Entailment'},
#  '93bb8a0e-e84c-4730-b559-22d912103993': {'Prediction': 'Contradiction'},
#  '0d7d2408-c51f-4b3a-a47f-6f0ee8dedacc': {'Prediction': 'Entailment'},
#  '102bbdcd-14ea-4dd5-a0bb-4cea343bb6ed': {'Prediction': 'Entailment'},
#  '559c1faa-17b6-42c7-9f63-0cd58df39bfa': {'Prediction': 'Entailment'},
#  'fa586070-5821-4a70-9812-9d7c6e5df330': {'Prediction': 'Contradiction'},
#  '8b9a4f04-25f6-45d2-a4fe-52e5bd3d22de': {'Prediction': 'Contradiction'},
#  '24e7fb4c-e279-4b61-8c7f-6dc6a09e8d55': {'Prediction': 'Contradiction'},
#  '851e1a1b-0b8e-4aef-a7e3-f06c036fe537': {'Prediction': 'Entailment'},
#  'b25a8f34-96ce-4ea1-a140-bf5b0ffe7f52': {'Prediction': 'Entailment'},
#  '9e3cf2a2-6713-4d07-adde-e334b49ca6ec': {'Prediction': 'Entailment'},
#  '4493c1ed-668a-44d4-9b3e-767f597d4fa8': {'Prediction': 'Contradiction'},
#  'b9074beb-a639-46ba-966b-b0db266efffc': {'Prediction': 'Entailment'},
#  '017ff04d-5509-4f54-863c-10201351e15d': {'Prediction': 'Contradiction'},
#  'cd250e97-c2b4-48cd-bcbe-55ea06fa9662': {'Prediction': 'Entailment'},
#  'a1a3cda8-7324-4270-aaf9-51ad1b40be07': {'Prediction': 'Entailment'},
#  '25551d37-108d-497a-8e75-825d8d707190': {'Prediction': 'Contradiction'},
#  'bc7b62ad-797e-419e-b5f9-888117aedf6b': {'Prediction': 'Contradiction'},
#  '5261c924-d9ef-43ed-8f2a-6c5b1552cc62': {'Prediction': 'Contradiction'},
#  'b5e896cf-e971-4fac-8dc6-a19e2c2d0a72': {'Prediction': 'Entailment'},
#  '2bf9e0d9-1195-4c03-b2bc-d491ff1cd174': {'Prediction': 'Contradiction'},
#  '1bf99d45-84a7-41cb-8263-d1ccb489bc66': {'Prediction': 'Contradiction'},
#  'adfed785-8da6-4bf4-836f-2dfadf0510b6': {'Prediction': 'Entailment'},
#  '523d79a3-ee67-4b2a-a1cb-20ed4ed45dc6': {'Prediction': 'Entailment'},
#  '2a0b1a83-299d-404d-96e5-67ee65173dde': {'Prediction': 'Entailment'},
#  '25cbaa44-4715-417b-9bd0-12fef06053b8': {'Prediction': 'Entailment'},
#  '0f31bc6a-a228-49c2-afff-4177ef850272': {'Prediction': 'Entailment'},
#  'bf3034ec-679a-42d1-9d24-69b51c602233': {'Prediction': 'Contradiction'},
#  'fbde81ad-0d06-4d2a-8baa-eb5eace1b3ec': {'Prediction': 'Entailment'},
#  '5e6797ef-370c-4b35-9e1d-37e694b538a6': {'Prediction': 'Contradiction'},
#  '28a88ea8-4cea-404c-9ad7-cb1be9c19d7f': {'Prediction': 'Entailment'},
#  '59a0bff2-c254-45f1-a6ae-2d847777db94': {'Prediction': 'Contradiction'},
#  '44412911-1f34-4841-a795-86eed5a209d7': {'Prediction': 'Entailment'},
#  '505ccc8c-b07a-4902-b8c3-4d3b4891779a': {'Prediction': 'Entailment'},
#  '58614e8d-770e-4bfe-b74b-e2d429ef072f': {'Prediction': 'Contradiction'},
#  'd118efb5-ea31-49ca-8e20-686c85081e94': {'Prediction': 'Contradiction'},
#  '5a181517-dbdc-4598-8955-ca1bfa380fa9': {'Prediction': 'Contradiction'},
#  '4adbcbcc-ae43-46af-a072-815d1e788f29': {'Prediction': 'Contradiction'},
#  '10f7c7cf-b7e2-4d21-8870-1fdbcc7937f5': {'Prediction': 'Entailment'},
#  'bd5d8368-5c1d-41b8-9fb3-f174da18744f': {'Prediction': 'Entailment'},
#  'd1a7cbaa-161a-4675-b8b7-67ae364be364': {'Prediction': 'Contradiction'},
#  '574106ef-1b9c-4540-a89f-5100a9bbe798': {'Prediction': 'Contradiction'},
#  '21c021d2-764d-4028-b945-2aeb525b9888': {'Prediction': 'Contradiction'},
#  'aefb2cc5-3101-416b-bae4-c9a1e7d8f39e': {'Prediction': 'Entailment'},
#  '320ec115-31c3-47bf-a819-93d514b91eb3': {'Prediction': 'Contradiction'},
#  'f45b251f-2fec-44b7-8fc0-dd0d06a44d3b': {'Prediction': 'Entailment'},
#  'd54a3e9d-5602-4cc3-934e-717f1da39792': {'Prediction': 'Entailment'},
#  'ce8a4f39-efff-4fd3-b850-4fc5c30270ef': {'Prediction': 'Entailment'},
#  '9d94e597-591d-409e-a8e2-b205a83533a5': {'Prediction': 'Entailment'},
#  '7e271bbd-26e8-422e-be5c-54d294da815a': {'Prediction': 'Contradiction'},
#  '6e4be816-3da7-4def-ab23-2a4fda805cd0': {'Prediction': 'Contradiction'},
#  '90cecb95-9f89-4747-81c3-96545edaf3f4': {'Prediction': 'Entailment'},
#  '137bb76f-a37e-4339-af7e-f0c647a01baa': {'Prediction': 'Entailment'},
#  'c41ed5cf-4629-4a4f-b564-197d705ec9cc': {'Prediction': 'Contradiction'},
#  '956a23c9-f76f-4492-9f00-acdbaf6ac083': {'Prediction': 'Entailment'},
#  'b87ab44e-6cbe-4567-98ff-bd820aa7edeb': {'Prediction': 'Entailment'},
#  'e2e8bb00-df98-49c2-a81b-e18ae21516aa': {'Prediction': 'Entailment'},
#  '6b3619d3-21ea-437e-bb0f-f124cf636ca5': {'Prediction': 'Contradiction'},
#  '0c03c804-4144-4d84-b740-8f6040f15acc': {'Prediction': 'Entailment'},
#  'c08aa0d8-5505-438c-b53a-934bd2ee570d': {'Prediction': 'Entailment'},
#  '0a1cb41e-a5f8-42ca-bec7-f9bc1291037c': {'Prediction': 'Contradiction'},
#  'ddf4fc68-7920-4212-ac8b-7453ebeb49fb': {'Prediction': 'Entailment'},
#  '09879638-e324-4f5d-a45e-f62f7e06f301': {'Prediction': 'Contradiction'},
#  'bc50160f-7490-4c30-b373-9474707b02b3': {'Prediction': 'Contradiction'},
#  'ee2fe2ab-dc6f-434e-b0dd-1deee5fb3d31': {'Prediction': 'Entailment'},
#  '7d818afc-93da-4098-a0f0-558bc0095687': {'Prediction': 'Contradiction'},
#  'e04edb9d-dc0e-44c4-abb9-3260b400e265': {'Prediction': 'Contradiction'},
#  '6af06b3f-dbbc-4679-a4a3-fe4b3757fdc0': {'Prediction': 'Entailment'},
#  'e63ac45b-c34b-4007-820a-30202893fc6f': {'Prediction': 'Entailment'},
#  'ff11f88f-a4cb-481e-bf56-afa5c0adda19': {'Prediction': 'Entailment'},
#  '29bed237-ccbb-460b-a50b-fbdc9e52fdd1': {'Prediction': 'Entailment'},
#  '88951a9e-179e-4284-9f98-141eb3d76369': {'Prediction': 'Contradiction'},
#  '71698d59-3bbe-4e8f-85c8-bf2110727155': {'Prediction': 'Entailment'},
#  '970f06b2-0935-4cde-a070-ddd7adb8ed5e': {'Prediction': 'Entailment'},
#  'd0168033-35eb-4032-b6e5-f81d9d3a9f7a': {'Prediction': 'Entailment'},
#  'cf4c4c98-b8b0-4ab8-85a8-1269da4d9fd8': {'Prediction': 'Entailment'},
#  '3d100b36-5765-4953-b072-b06f38b6958c': {'Prediction': 'Entailment'},
#  'f0ca21dc-bf98-4c8b-b08e-d0821905846a': {'Prediction': 'Entailment'},
#  'b88356ec-038f-4f5c-bf14-750059dbba4f': {'Prediction': 'Contradiction'},
#  '56e9308b-f718-4831-8e56-4b18982e4a2c': {'Prediction': 'Entailment'},
#  '86ee12d2-2095-4ece-a7d6-f9494b51f3a6': {'Prediction': 'Entailment'},
#  '8ef6757e-e789-4a70-9cf3-e2e8050c9f15': {'Prediction': 'Entailment'},
#  '52d4cfdf-7677-4f4c-8020-4f5271393df9': {'Prediction': 'Contradiction'},
#  'a8932849-e870-422e-a81a-1b43d9622082': {'Prediction': 'Entailment'},
#  '06a1adac-dee0-4d9b-83c6-0996391e40d0': {'Prediction': 'Entailment'},
#  'c2d6b8ba-8238-49b7-b9a1-de2ffdabe324': {'Prediction': 'Contradiction'},
#  '496667f2-e493-4b4e-a257-7b8de3833e8b': {'Prediction': 'Entailment'},
#  '47512f16-9809-4150-a101-1fb7256c5bf3': {'Prediction': 'Contradiction'},
#  'd904b234-fed6-473e-bd40-8f37f4a4e440': {'Prediction': 'Entailment'},
#  '90c519e9-7981-4a72-af6a-cc032657458a': {'Prediction': 'Contradiction'},
#  'd9e7c0cc-0850-4a8e-b389-092dfdc623fc': {'Prediction': 'Contradiction'},
#  '05fbffcf-c1a0-40f9-95dd-8e9010005773': {'Prediction': 'Contradiction'},
#  '7814620b-23de-463b-8fd1-efdf51ce26b3': {'Prediction': 'Contradiction'},
#  'ae548af6-b401-4dac-9824-50b2a566e7bd': {'Prediction': 'Entailment'},
#  'a60074c0-d7a6-47cc-b980-ee1c0a791f66': {'Prediction': 'Entailment'},
#  'd9d506ef-20ed-44e2-9809-07cb0772535b': {'Prediction': 'Entailment'},
#  '1defe036-8290-4a01-bec7-f75305d1e88e': {'Prediction': 'Entailment'},
#  '1fe68175-6ac4-4439-818f-94758e6bd306': {'Prediction': 'Contradiction'},
#  'fac10570-e1ed-4b0a-b847-55eb25265d25': {'Prediction': 'Entailment'},
#  '152fc619-bbb0-40ff-aa3e-5722f62f6a84': {'Prediction': 'Contradiction'},
#  '228308ea-2483-4311-a975-ca974ff797c6': {'Prediction': 'Contradiction'},
#  'eca5c391-f479-448d-bff8-313a7df673b4': {'Prediction': 'Contradiction'},
#  '17660aaf-9218-4119-b00c-f3b863718e97': {'Prediction': 'Contradiction'},
#  '291150cd-0d45-46c7-9a44-d781098bc3eb': {'Prediction': 'Contradiction'},
#  '403ad287-6e25-4db0-a66b-fe4a7f15a983': {'Prediction': 'Entailment'},
#  'c389c3cc-2e76-4219-996d-3aa5a925fec7': {'Prediction': 'Entailment'},
#  '6f0571f4-e1da-4732-9bdf-8c07bea059c1': {'Prediction': 'Contradiction'},
#  'c6ca9f93-1abb-4c01-bdfb-aa17c5028ec8': {'Prediction': 'Contradiction'},
#  'b16d4167-cb81-44c0-b20d-d1ecbf0bc094': {'Prediction': 'Contradiction'},
#  '36cbd8dd-9c77-496c-ab43-af1942c86339': {'Prediction': 'Contradiction'},
#  '50dae016-a6b4-4ee6-a66a-bf35587cd835': {'Prediction': 'Entailment'},
#  'c63468c0-324f-4528-b83f-a588ccf7b680': {'Prediction': 'Contradiction'},
#  'ef2af81d-e19c-49c9-8ff0-309b87eb6f38': {'Prediction': 'Entailment'},
#  '4714a31c-c7ca-49e2-aa71-6665b65ed04f': {'Prediction': 'Contradiction'},
#  '570b88e9-5036-4ea8-80db-0f48696700af': {'Prediction': 'Contradiction'},
#  'f7de4d97-31e4-48e0-ab1a-1e3d8a152e8b': {'Prediction': 'Entailment'},
#  '8d685159-80a2-4b2c-8ca3-066d03e1cf66': {'Prediction': 'Contradiction'},
#  '5e93b7d7-89d9-47cd-98b4-5897823889fa': {'Prediction': 'Entailment'},
#  '2e42ac97-e353-4bbc-b61e-391e0c092689': {'Prediction': 'Entailment'},
#  '0585f6bd-d582-4fc9-b96b-1355fa083e33': {'Prediction': 'Contradiction'},
#  '4f1bafd9-361f-4981-b6fd-46af736141b4': {'Prediction': 'Entailment'},
#  'c91a6c5a-27f1-4e7b-8f91-34e3d2236e8b': {'Prediction': 'Contradiction'},
#  '0bb34f7b-d21a-4057-876a-25c722e6d50e': {'Prediction': 'Contradiction'},
#  '3f15d923-bf66-4188-8714-c9ae4921de1f': {'Prediction': 'Entailment'},
#  '9562c377-c748-46d7-a5f2-eb492d20e477': {'Prediction': 'Contradiction'},
#  '1e24905e-7bf9-4a79-8157-8948f108ecb7': {'Prediction': 'Entailment'},
#  '57656a6d-8e1c-4cb8-b80d-605174d0577c': {'Prediction': 'Entailment'},
#  'c5ece9f7-9119-4fa2-b60d-f2f15c68ae02': {'Prediction': 'Contradiction'},
#  '8f8be6b6-df75-4757-bc64-b2fbc8849f70': {'Prediction': 'Entailment'},
#  '520f44e8-b74b-44a6-a7cf-496275847af1': {'Prediction': 'Entailment'},
#  '0c902de2-30b5-4ab8-9739-70be987d043a': {'Prediction': 'Entailment'},
#  '8b98421d-1cec-41bd-b25e-2e73c362193a': {'Prediction': 'Entailment'},
#  '62441471-f329-4540-9d4e-dc34c4d08d59': {'Prediction': 'Contradiction'},
#  'd1d5671f-79dd-4fd3-a4aa-b5f81d8a944f': {'Prediction': 'Contradiction'},
#  'cf45d975-0c29-4cf3-8f21-c245482a2b32': {'Prediction': 'Entailment'},
#  'fb011e19-d4fb-4e6c-b7c9-7a7238f78970': {'Prediction': 'Contradiction'},
#  'fd800c89-d30c-4a9a-970b-5385deeab52f': {'Prediction': 'Entailment'},
#  'd0212d75-c952-4ad3-ae36-bbf675eae985': {'Prediction': 'Contradiction'},
#  '5d98b3df-684a-466d-93da-5a672f602db6': {'Prediction': 'Entailment'},
#  '61a6a476-9283-4cde-89e7-5f1405f690c1': {'Prediction': 'Contradiction'},
#  'bde8a5a0-02fc-4b6e-a91a-a56c420d9c3b': {'Prediction': 'Contradiction'},
#  'fabf3f7a-48df-4940-93e2-8cbe976c4246': {'Prediction': 'Contradiction'},
#  'e8351b8b-d707-4766-b875-777557f0653f': {'Prediction': 'Contradiction'},
#  '5dea6bbb-13c3-470c-98a6-3879f17de8c7': {'Prediction': 'Entailment'},
#  '5c00eee7-bb33-45e5-97c6-4cfc34946cdf': {'Prediction': 'Entailment'},
#  'c3f4b547-8d11-42ba-800c-7ccbe1283741': {'Prediction': 'Contradiction'},
#  '451c8e9e-03c1-4b7a-9b84-5129c5623f1b': {'Prediction': 'Entailment'},
#  '7723c9e5-e80e-4ef6-b56d-ee26f8423d90': {'Prediction': 'Contradiction'},
#  'b6b719ca-e7f3-4254-a1a0-2946acbcd2fd': {'Prediction': 'Contradiction'},
#  'b3f59657-9278-41be-b740-433b0d38fdd5': {'Prediction': 'Contradiction'},
#  'bcc9a793-5002-4cd9-a5b7-af5a1ceca35a': {'Prediction': 'Contradiction'},
#  '3a141563-97b8-4154-8c9c-f1f551ec7969': {'Prediction': 'Entailment'},
#  '64441aad-b959-41bb-aa81-2f594d00b70c': {'Prediction': 'Contradiction'},
#  '5fcf6210-c07a-4b8e-9944-c2f0714e4d69': {'Prediction': 'Entailment'},
#  '05530068-7a95-46f6-88d2-84e53ee2ff35': {'Prediction': 'Entailment'},
#  '40fc3a97-0a5d-4f19-ba94-7c4668d0538d': {'Prediction': 'Entailment'},
#  'f0f8a0a6-1148-4592-a9b4-27c005038900': {'Prediction': 'Entailment'},
#  '2cde3c46-f21a-4177-afc8-94f851854b98': {'Prediction': 'Entailment'},
#  'b3679900-ab99-4a84-83e0-fc1122a43beb': {'Prediction': 'Entailment'},
#  '21afdaec-2db5-42b3-b201-b2dee4e23cb7': {'Prediction': 'Contradiction'},
#  'b9b69888-f771-4a3a-b6f0-825510997cca': {'Prediction': 'Entailment'},
#  '6d7c7740-c399-4d73-82c8-2ef0d4739341': {'Prediction': 'Entailment'},
#  '15577bb6-3b4d-4373-ae58-eb0bf0c34954': {'Prediction': 'Entailment'},
#  '315f4573-d5b1-4cbc-9efb-74c27a98dc6d': {'Prediction': 'Contradiction'},
#  'fe6baecc-71eb-4b15-ba15-66d57539c702': {'Prediction': 'Entailment'},
#  'b581bb7b-6aaa-4c8a-81a0-c5e6a58ebcdf': {'Prediction': 'Entailment'},
#  'f9e4988c-a325-40bc-8220-e7d0c404fd37': {'Prediction': 'Entailment'},
#  'ef2352dc-a976-47c6-91cd-6666e3f7b55a': {'Prediction': 'Contradiction'},
#  'ce40b0b9-d8d4-45f4-a2dc-4adb8e7103ac': {'Prediction': 'Entailment'},
#  '9cd25233-1d76-4d0d-a571-ce8fee279757': {'Prediction': 'Contradiction'},
#  '0c27bcc9-3108-4d4a-901a-22718c22d288': {'Prediction': 'Contradiction'},
#  '464e2cd9-6c59-4692-a3fc-083c374f4a5c': {'Prediction': 'Contradiction'},
#  '438a978d-ac7e-4260-bb24-d2129cb3dfc6': {'Prediction': 'Contradiction'},
#  '863f7074-fb4b-4c82-9e30-bb785f85f816': {'Prediction': 'Contradiction'},
#  'eeb18145-fc5f-41d7-bce3-245d21000e7b': {'Prediction': 'Entailment'},
#  'ad5ca7e8-3e5d-43b8-9618-99f56fc70290': {'Prediction': 'Contradiction'},
#  '3eb3c09a-b46f-49bf-84d6-7aeb1ba0d2a5': {'Prediction': 'Contradiction'},
#  '7dd6b446-5585-4660-8bc7-e9811af66268': {'Prediction': 'Entailment'},
#  'f45bbf0b-4acd-4166-81a6-6b407cff87ca': {'Prediction': 'Entailment'},
#  'b23563cf-e6c4-4279-92b7-39d5e4de96d2': {'Prediction': 'Contradiction'},
#  'd921df56-8a29-45a9-bb0b-66ba14dbc193': {'Prediction': 'Contradiction'},
#  '006c9dd6-c568-4497-81b7-c954568a3b4a': {'Prediction': 'Contradiction'},
#  '585b42d5-c81a-482a-a6bf-b7db6c6edcfb': {'Prediction': 'Contradiction'},
#  '620b6390-df07-45fe-9ef9-55a32521c740': {'Prediction': 'Entailment'},
#  'eb088d03-7fdc-48bd-9175-0e7a9cfc7b9a': {'Prediction': 'Entailment'},
#  '9334239a-f4f1-4192-a35d-93c25c41328d': {'Prediction': 'Entailment'},
#  'feca7444-9108-45e9-b722-4f0a207376c7': {'Prediction': 'Entailment'},
#  '2e2a005f-232f-457a-880e-c3950bc58df6': {'Prediction': 'Entailment'},
#  'b95564b8-cdbe-45d0-be91-764d6768e5f9': {'Prediction': 'Contradiction'},
#  '2ce0822a-fcf8-4010-950c-0d3a8dc2cb00': {'Prediction': 'Contradiction'},
#  'e6bba244-c154-4143-a5f2-5f8b1c304a97': {'Prediction': 'Contradiction'},
#  'a5657dcd-1ee5-44f6-bb21-e718259c4b2e': {'Prediction': 'Contradiction'},
#  '8180d5e0-b284-45fe-a390-0c3a54dc663f': {'Prediction': 'Contradiction'},
#  '87fda661-4348-4078-b3e7-915893241ab0': {'Prediction': 'Contradiction'},
#  '4bc60955-6137-4496-b780-5fb8e90dc3ed': {'Prediction': 'Entailment'},
#  '7ad6c209-8893-4a2d-963d-24666ef93a80': {'Prediction': 'Contradiction'},
#  'a06166e6-12c9-49ba-ad3a-7fcfb5234174': {'Prediction': 'Entailment'},
#  '73feb437-66f3-44fd-8d9c-ab3204e6eac3': {'Prediction': 'Entailment'},
#  '927d72b0-1f55-4803-9a86-40838c08f923': {'Prediction': 'Entailment'},
#  '19e0531d-7907-46b0-ab0c-e616746498e9': {'Prediction': 'Entailment'},
#  'fc281ab7-f956-47d7-a938-8778fef1bca0': {'Prediction': 'Contradiction'},
#  '6261a694-0407-4840-8a87-3a0c6f9dea4f': {'Prediction': 'Contradiction'},
#  '9730b1a6-e9cd-4fd6-b1e4-9916b5903c63': {'Prediction': 'Entailment'},
#  '2fb3af20-adda-4fee-860a-ce376d3a0bb2': {'Prediction': 'Entailment'},
#  'f8dbd18d-2b55-4f0f-92a7-db3b1ecc3b6d': {'Prediction': 'Contradiction'},
#  'dd27a6e7-3b83-4a84-bc40-5ba39617a1c1': {'Prediction': 'Contradiction'},
#  '113abff0-a728-40a6-b637-8bd60a53e626': {'Prediction': 'Entailment'},
#  '1cb125fb-0be1-49c6-b68b-64b525278c9c': {'Prediction': 'Entailment'},
#  'fd0b22b0-c86d-4460-bf53-310901404ef5': {'Prediction': 'Entailment'},
#  'c0151b24-14ab-4837-965d-88bb8115a560': {'Prediction': 'Contradiction'},
#  '1d66459b-4624-4ea0-9cda-992c4146a454': {'Prediction': 'Entailment'},
#  '73981f59-887e-4778-a78a-0bf7b7a405b7': {'Prediction': 'Contradiction'},
#  'dbd5f70e-0fa9-4b5e-af0e-0ad9efc49bc6': {'Prediction': 'Contradiction'},
#  '5599d5d8-3a7b-41ce-a00c-6e0b609b618d': {'Prediction': 'Contradiction'},
#  '84942825-f636-4dcf-af2e-172012c0cc9d': {'Prediction': 'Entailment'},
#  'e4b448ba-15ad-4cf8-9343-782d45166891': {'Prediction': 'Entailment'},
#  '27aec260-8dcc-4611-8389-dc9c10d3518d': {'Prediction': 'Contradiction'},
#  '943f62ca-d87c-4a5e-9355-6750d7d9b58f': {'Prediction': 'Entailment'},
#  'e53898b8-422f-4317-b2f6-c487409b0750': {'Prediction': 'Entailment'},
#  '7b819ac1-92e6-41ce-881c-0f4581a690ee': {'Prediction': 'Entailment'},
#  'c09c08d5-189f-4e15-acb8-2c3cb235aaa6': {'Prediction': 'Entailment'},
#  '99a6cb19-b6d8-4cb7-84e1-be559854caa6': {'Prediction': 'Entailment'},
#  '70539b18-50b0-43f7-b676-2143de2dc3e8': {'Prediction': 'Entailment'},
#  '52b055fd-9e0d-41ad-9eb7-1a724cbc0112': {'Prediction': 'Entailment'},
#  'dcfc0053-b963-4542-ae02-228d3d2bd98e': {'Prediction': 'Contradiction'},
#  'f706897d-d54e-4449-8bc7-da0bd6fbad01': {'Prediction': 'Entailment'},
#  'c39ec45a-1664-49aa-8356-abbecf045001': {'Prediction': 'Entailment'},
#  'eb555e01-0a12-45a1-99ad-7d7dafbe8912': {'Prediction': 'Entailment'},
#  'c43583e4-da5f-42b3-ad3d-7ba8b6b28f2b': {'Prediction': 'Contradiction'},
#  '094e7aec-88db-4ad0-b995-ece8587fd48b': {'Prediction': 'Contradiction'},
#  '20c98ba5-ca61-4afe-af57-6de08705a5cd': {'Prediction': 'Entailment'},
#  '58fa0ef4-0355-42bc-8378-fef98752b05e': {'Prediction': 'Contradiction'},
#  'b033d45a-c039-42de-a073-3c051c6f1e3c': {'Prediction': 'Entailment'},
#  '75c55f70-aa52-4794-aae7-3a355f1a76e9': {'Prediction': 'Contradiction'},
#  '070ba2da-932a-4a62-861e-3f2c89630b4d': {'Prediction': 'Contradiction'},
#  '76d498ce-037c-4f7e-8cbb-450d8f6019ec': {'Prediction': 'Entailment'},
#  'dfd8e736-5ef2-4d36-b124-9382e72f982d': {'Prediction': 'Entailment'},
#  'a4a2c0ba-3fa9-4fad-9258-7e517ae85e25': {'Prediction': 'Entailment'},
#  'e8e3fedb-075d-440e-bf2e-baec76f96cca': {'Prediction': 'Entailment'},
#  'b53a2698-dfb0-416d-9f3e-2e800a360b3e': {'Prediction': 'Entailment'},
#  'cd067ee2-ed1d-403b-aa50-d61a3399fda3': {'Prediction': 'Contradiction'},
#  '8b50bdc1-1722-403b-a854-adeaacd02acb': {'Prediction': 'Contradiction'}}
