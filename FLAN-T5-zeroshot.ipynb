# %%
import os
import json

import torch
import tqdm

from transformers import T5Tokenizer, T5ForConditionalGeneration

# %%
split = "train.json"
data = json.load(open(f"Complete_dataset/{split}"))
files = os.listdir("Complete_dataset/CT json/")
files.remove(".DS_Store")

# %%
files_data = {file[:-5]:json.load(open(f"Complete_dataset/CT json/{file}")) for file in files}

# %%
data_expanded = []
for _id, value in data.items():
    temp = {}
    temp["id"] = _id
    p_nctid = value["Primary_id"]
    s_nctid = value.get("Secondary_id")
    section_id = value["Section_id"]
    statement = value["Statement"]
    primary_evidence = files_data[p_nctid][section_id]
    temp["statement"] = statement
    temp["primary_evidence"] = primary_evidence
    temp["label"] = value["Label"]
    
    if s_nctid is not None:
        secondary_evidence = files_data[s_nctid][section_id]
        temp["secondary_evidence"] = secondary_evidence
    
    data_expanded.append(temp)

# %%
tokenizer = T5Tokenizer.from_pretrained("google/flan-t5-xl")

# %%
model = T5ForConditionalGeneration.from_pretrained("google/flan-t5-xl", cache_dir="/mnt/data/huggingface_cache", device_map="auto",)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
def get_input_text(premise, hypothesis):
    options_prefix = "OPTIONS:\n- "
    separator = "\n- "
    options_ = options_prefix + f"{separator}".join(["Entailment","Contradiction"])
    return f"{premise} \n Question: Does this imply that {hypothesis}? {options_}"

# %%
samples = []
for sample in data_expanded:
    primary_evidence = "".join(sample['primary_evidence'])
    sentence = f"Primary trial evidence are {primary_evidence}"
    secondary_evidence = sample.get("secondary_evidence")
    if secondary_evidence:
        secondary_evidence = "".join(sample['secondary_evidence'])
        sentence = f"{sentence} Secondary trial evidence are {secondary_evidence}"
    input_text = get_input_text(sentence, sample['statement'])
    temp = {"text":input_text, "label":sample['label']}
    samples.append(temp)

# %%
labels = []
pred = []
with torch.inference_mode():
    for sample in tqdm.tqdm(samples):
        labels.append(sample["label"])
        input_ids = tokenizer(sample["text"], return_tensors="pt",).input_ids.to("cuda")
        outputs = model.generate(input_ids)
        pred.append(tokenizer.decode(outputs[0]))
# Out:
#   0%|          | 0/1700 [00:00<?, ?it/s]/home/kamal_raj/transformers/src/transformers/generation/utils.py:1234: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 20 (`generation_config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
#   0%|          | 1/1700 [00:01<50:26,  1.78s/it]Token indices sequence length is longer than the specified maximum sequence length for this model (1258 > 512). Running this sequence through the model will result in indexing errors
# 100%|██████████| 1700/1700 [11:05<00:00,  2.55it/s]

# %%
pred
# Out:
# ['<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> No</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> No</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> No</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> No</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> No</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> No</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> No</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> No</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  '<pad> Contradiction</s>',
#  '<pad> Entailment</s>',
#  ...]

# %%
pred = [p[5:][:-4].strip() for p in pred]

# %%
set(pred)
# Out:
# {'Contradiction', 'Entailment', 'No', 'Yes'}

# %%
labels[0:10]
# Out:
# ['Contradiction',
#  'Contradiction',
#  'Entailment',
#  'Contradiction',
#  'Contradiction',
#  'Contradiction',
#  'Contradiction',
#  'Contradiction',
#  'Entailment',
#  'Contradiction']

# %%
from sklearn.metrics import f1_score

# %%
f1_score(pred, labels,pos_label="Entailment")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 f1_score(pred, labels,pos_label="Entailment")
#
# File ~/.virtualenvs/hf_env/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1146, in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1011 def f1_score(
#    1012     y_true,
#    1013     y_pred,
#    (...)
#    1019     zero_division="warn",
#    1020 ):
#    1021     """Compute the F1 score, also known as balanced F-score or F-measure.
#    1022
#    1023     The F1 score can be interpreted as a harmonic mean of the precision and
#    (...)
#    1144     array([0.66666667, 1.        , 0.66666667])
#    1145     """
# -> 1146     return fbeta_score(
#    1147         y_true,
#    1148         y_pred,
#    1149         beta=1,
#    1150         labels=labels,
#    1151         pos_label=pos_label,
#    1152         average=average,
#    1153         sample_weight=sample_weight,
#    1154         zero_division=zero_division,
#    1155     )
#
# File ~/.virtualenvs/hf_env/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1287, in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    1158 def fbeta_score(
#    1159     y_true,
#    1160     y_pred,
#    (...)
#    1167     zero_division="warn",
#    1168 ):
#    1169     """Compute the F-beta score.
#    1170
#    1171     The F-beta score is the weighted harmonic mean of precision and recall,
#    (...)
#    1284     array([0.71..., 0.        , 0.        ])
#    1285     """
# -> 1287     _, _, f, _ = precision_recall_fscore_support(
#    1288         y_true,
#    1289         y_pred,
#    1290         beta=beta,
#    1291         labels=labels,
#    1292         pos_label=pos_label,
#    1293         average=average,
#    1294         warn_for=("f-score",),
#    1295         sample_weight=sample_weight,
#    1296         zero_division=zero_division,
#    1297     )
#    1298     return f
#
# File ~/.virtualenvs/hf_env/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1573, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1571 if beta < 0:
#    1572     raise ValueError("beta should be >=0 in the F-beta score")
# -> 1573 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1575 # Calculate tp_sum, pred_sum, true_sum ###
#    1576 samplewise = average == "samples"
#
# File ~/.virtualenvs/hf_env/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1391, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1389         if y_type == "multiclass":
#    1390             average_options.remove("samples")
# -> 1391         raise ValueError(
#    1392             "Target is %s but average='binary'. Please "
#    1393             "choose another average setting, one of %r." % (y_type, average_options)
#    1394         )
#    1395 elif pos_label not in (None, 1):
#    1396     warnings.warn(
#    1397         "Note that pos_label (set to %r) is ignored when "
#    1398         "average != 'binary' (got %r). You may use "
#    (...)
#    1401         UserWarning,
#    1402     )
#
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].

# %%
prediction_dict = {}
for _id,pred_x in zip(data, pred):
    prediction_dict[str(_id)] = {"Prediction":pred_x}

# %%
json.dump(prediction_dict, open("results.json",'w'),indent=4)
# !zip results_xl_zero_dev.zip results.json
# Out:
# updating: results.json (deflated 73%)

# %%
from sklearn.metrics import f1_score
uuid_list = list(prediction_dict.keys())
results_pred = []
gold_labels = []
for i in range(len(uuid_list)):
    if prediction_dict[uuid_list[i]]["Prediction"] in ["Entailment", "Yes"]:
        results_pred.append(1)
    else:
        results_pred.append(0)
    if data[uuid_list[i]]["Label"] in ["Entailment", "No"]:
        gold_labels.append(1)
    else:
        gold_labels.append(0)
f1_score(gold_labels,results_pred)

# %%
# Out:
# 0.6754896770778189
